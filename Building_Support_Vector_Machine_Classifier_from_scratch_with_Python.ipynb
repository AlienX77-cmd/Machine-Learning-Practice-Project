# %% [markdown]
# <a href="https://colab.research.google.com/github/AlienX77-cmd/Machine-Learning-Practice-Project/blob/main/Building_Support_Vector_Machine_Classifier_from_scratch_with_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Support Vector Machine Classifier**

# %% [markdown]
# ![support-vector-machine-algorithm5.png](data:image/png;base64,...)

# %% [markdown]
# **Equation of the Hyperplane:**
#
# **y = wx - b**

# %% [markdown]
# ![SVM building 1.png](data:image/png;base64,...)![SVM building 2.png](data:image/png;base64,...)

# %% [markdown]
# **Gradient Descent:**
#
# Gradient Descent is an optimization algorithm used for minimizing the loss function in various machine learning algorithms. It is used for updating the parameters of the learning model.
#
# w = w - α*dw
#
# b = b - α*db

# %% [markdown]
# ![SVM building 3.png](data:image/png;base64,...)![SVM building 3.1.png](data:image/png;base64,...)

# %% [markdown]
# **Learning Rate:**
#
# Learning rate is a tuning parameter in an optimization algorithm that determines the step size at each iteration while moving toward a minimum of a loss function.

# %% [markdown]
# ![SVM building 4.png](data:image/png;base64,...)

# %% [markdown]
# ![SVM building 5.png](data:image/png;base64,...)

# %%
import numpy as np

# %%
# Support Vector Machine Classifier

class SVM_classifier():

  # Initiating the hyperparameters
  def __init__(self, learning_rate, no_of_iterations, lambda_parameter):
    self.learning_rate = learning_rate
    self.no_of_iterations = no_of_iterations
    self.lambda_parameter = lambda_parameter


  # Fitting the SVM classifier to the dataset
  def fit(self, X, Y):
    
    # m  --> number of Data points --> number of rows
    # n  --> number of input features --> number of columns
    self.m, self.n = X.shape

    # Initiating the weight value and bias value
    self.w = np.zeros(self.n)
    self.b = 0
    self.X = X
    self.Y = Y

    # Implementing Gradient Descent Algorithm for Optimization
    for i in range(self.no_of_iterations):
      self.update_weights()
  
  # Updating the weight and bias value
  def update_weights(self):

    # Label encoding
    Y_label = np.where(self.Y <= 0, -1, 1) #if self.Y <=0 then return -1 else return 1

    # Gradients (dw, db)
    for index, x_i in enumerate(self.X):
      condition = Y_label[index] * (np.dot(x_i, self.w) - self.b) >= 1 #True or False

      if (condition == True):
        dw = 2 * self.lambda_parameter * self.w
        db = 0

      else:
        dw = 2 * self.lambda_parameter * self.w - np.dot(x_i, Y_label[index])
        dw = Y_label[index]

      self.w = self.w - self.learning_rate * dw
      self.b = self.b - self.learning_rate * db 

  # Predict the Label for a give input value
  def predict(self, X):

    output = np.dot(X, self.w) - self.b

    predicted_labels_sign = np.sign(output)

    y_hat = np.where(predicted_labels_sign <= -1, 0, 1)

    return y_hat

# %% [markdown]
# **How to use**
#
#
# ```
# model = SVM_classifier()
# model.fit(X_train, Y_train)
# prediciton = model.predict(X_test)
# ```

# %%
#Example of enumerate function

my_list = [10, 20, 30, 40, 50]

for index, my_list_i in enumerate(my_list):
  print(index, my_list_i)
# Out:
# 0 10
# 1 20
# 2 30
# 3 40
# 4 50
